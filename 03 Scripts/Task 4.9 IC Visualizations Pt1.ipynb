# %% [markdown]
# # Importing libraries

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\cavba\Documents\Instacart Basket Analysis"

# %%
customers = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv' ), index_col = False)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
customers.tail()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %%
customers.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %% [markdown]
# ### Updating column headings

# %%
#Changing heading from Surname to LastName
customers = customers.rename(columns={'Surnam': 'LastName'})

# %%
# Changing columns name from n_dependents to number_of_dependants
customers = customers.rename(columns={'n_dependants':'number_of_dependants'})

# %%
#changing fam_status to family_status
customers = customers.rename(columns={'fam_status':'family_status'})

# %%
customers.head()
# Out:
#    user_id First Name  LastName  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %% [markdown]
# Changing the headings makes it easier to understand what each field represents. I'm choosing to leave all exisitng columns in the data set because they could be used for different comparisons later.

# %%
customers.describe()
# Out:
#              user_id            Age  number_of_dependants         income
# count  206209.000000  206209.000000         206209.000000  206209.000000
# mean   103105.000000      49.501646              1.499823   94632.852548
# std     59527.555167      18.480962              1.118433   42473.786988
# min         1.000000      18.000000              0.000000   25903.000000
# 25%     51553.000000      33.000000              0.000000   59874.000000
# 50%    103105.000000      49.000000              1.000000   93547.000000
# 75%    154657.000000      66.000000              3.000000  124244.000000
# max    206209.000000      81.000000              3.000000  593901.000000

# %% [markdown]
# ## Data Consistency Checks

# %%
# Check for mixed types
for col in customers.columns.tolist():
  weird = (customers[[col]].applymap(type) != customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (customers[weird]) > 0:
    print (col)
# Out:
# First Name

# %% [markdown]
# Since the First Name data type is already set as a string I will leave it as is

# %%
# Checking for empty fields
customers.isnull().sum()
# Out:
# user_id                     0
# First Name              11259
# LastName                    0
# Gender                      0
# STATE                       0
# Age                         0
# date_joined                 0
# number_of_dependants        0
# family_status               0
# income                      0
# dtype: int64

# %%
# Creating a subset of customers to view missing values
df_nan = customers[customers['First Name'].isnull()==True]

# %%
df_nan
# Out:
#         user_id First Name  LastName  Gender         STATE  Age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         number_of_dependants family_status  income
# 53                         2       married   41709
# 73                         0        single   82518
# 82                         3       married  117099
# 99                         1       married  155673
# 105                        3       married  151819
# ...                      ...           ...     ...
# 206038                     3       married   87783
# 206044                     2       married  108488
# 206090                     1       married   45275
# 206162                     0        single   56325
# 206171                     2       married   59222
#
# [11259 rows x 10 columns]

# %%
customers.shape
# Out:
# (206209, 10)

# %%
#Creating a subset without null First Name values
customers_clean = customers[customers['First Name'].isnull()==False]

# %%
customers_clean.shape
# Out:
# (194950, 10)

# %% [markdown]
# The shape if the subset is accurate excluding all of the empty First Name fields

# %%
#Checking to make sure all null values are gone
customers_clean.isnull().sum()
# Out:
# user_id                 0
# First Name              0
# LastName                0
# Gender                  0
# STATE                   0
# Age                     0
# date_joined             0
# number_of_dependants    0
# family_status           0
# income                  0
# dtype: int64

# %%
# Checking for duplicates
df_dups = customers_clean[customers_clean.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, LastName, Gender, STATE, Age, date_joined, number_of_dependants, family_status, income]
# Index: []

# %%
df_dups.shape
# Out:
# (0, 10)

# %% [markdown]
# There are no duplicates in the custoemrs_clean data set

# %%
#Exporting cleaned customers data set to prepared data folder
customers_clean.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'customers_cleaned'))

# %%
customers_clean.head()
# Out:
#    user_id First Name  LastName  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    number_of_dependants family_status  income
# 0                     3       married  165665
# 1                     0        single   59285
# 2                     2       married   99568
# 3                     0        single   42049
# 4                     1       married   40374

# %%
ords_prods_merge = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_frequencies.csv'))

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           1           1  Chocolate Sandwich Cookies        61
# 2           2           1  Chocolate Sandwich Cookies        61
# 3           3           1  Chocolate Sandwich Cookies        61
# 4           4           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  ...  \
# 0             19     5.8   3139998      138    prior            28  ...
# 1             19     5.8   1977647      138    prior            30  ...
# 2             19     5.8    389851      709    prior             2  ...
# 3             19     5.8    652770      764    prior             1  ...
# 4             19     5.8   1813452      764    prior             3  ...
#
#      price_range_loc   busiest day        Result  busiest_period_of_day  \
# 0  Mid-range product  Regular busy  regular days            Most orders
# 1  Mid-range product  Regular busy  regular days            Most orders
# 2  Mid-range product   Busiest day  busiest days         Average orders
# 3  Mid-range product  Regular busy  slowest days            Most orders
# 4  Mid-range product    Least busy  slowest days            Most orders
#
#    max_order      loyalty_flag  avg_price spending_flag median_order  \
# 0         32  Regular customer  14.790541  High Spender          8.0
# 1         32  Regular customer  14.790541  High Spender          8.0
# 2          5      New customer   3.062500   Low Spender          8.0
# 3          3      New customer   2.017241   Low Spender          9.0
# 4          3      New customer   2.017241   Low Spender          9.0
#
#       frequency_flag
# 0  Frequent Customer
# 1  Frequent Customer
# 2  Frequent Customer
# 3  Frequent Customer
# 4  Frequent Customer
#
# [5 rows x 26 columns]

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19403302 entries, 0 to 19403301
# Data columns (total 26 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   product_id              int64
#  2   product_name            object
#  3   aisle_id                int64
#  4   department_id           int64
#  5   prices                  float64
#  6   order_id                int64
#  7   user_id                 int64
#  8   eval_set                object
#  9   order_number            int64
#  10  orders_day_of_the_week  int64
#  11  order_hour_of_day       int64
#  12  days_since_prior_order  float64
#  13  add_to_cart_order       int64
#  14  reordered               int64
#  15  _merge                  object
#  16  price_range_loc         object
#  17  busiest day             object
#  18  Result                  object
#  19  busiest_period_of_day   object
#  20  max_order               int64
#  21  loyalty_flag            object
#  22  avg_price               float64
#  23  spending_flag           object
#  24  median_order            float64
#  25  frequency_flag          object
# dtypes: float64(4), int64(12), object(10)
# memory usage: 3.8+ GB

# %%
ords_prods_merge.isnull().sum()
# Out:
# Unnamed: 0                      0
# product_id                      0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# order_id                        0
# user_id                         0
# eval_set                        0
# order_number                    0
# orders_day_of_the_week          0
# order_hour_of_day               0
# days_since_prior_order    1238282
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# price_range_loc                 0
# busiest day                     0
# Result                          0
# busiest_period_of_day           0
# max_order                       0
# loyalty_flag                    0
# avg_price                       0
# spending_flag                   0
# median_order                    4
# frequency_flag                  4
# dtype: int64

# %%
ords_prods_merge.drop(columns = ['Unnamed: 0'])
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 19403297       29662   Potato Yukon Gold Organic        83              4
# 19403298       29662   Potato Yukon Gold Organic        83              4
# 19403299       29662   Potato Yukon Gold Organic        83              4
# 19403300       29662   Potato Yukon Gold Organic        83              4
# 19403301       29662   Potato Yukon Gold Organic        83              4
#
#           prices  order_id  user_id eval_set  order_number  \
# 0            5.8   3139998      138    prior            28
# 1            5.8   1977647      138    prior            30
# 2            5.8    389851      709    prior             2
# 3            5.8    652770      764    prior             1
# 4            5.8   1813452      764    prior             3
# ...          ...       ...      ...      ...           ...
# 19403297     3.6    194185   203834    prior            33
# 19403298     3.6   2082979   203834    prior            36
# 19403299     3.6    239800   203834    prior            43
# 19403300     3.6   2073065   203834    prior            52
# 19403301     3.6   2426370   203880    prior            10
#
#           orders_day_of_the_week  ...    price_range_loc   busiest day  \
# 0                              6  ...  Mid-range product  Regular busy
# 1                              6  ...  Mid-range product  Regular busy
# 2                              0  ...  Mid-range product   Busiest day
# 3                              3  ...  Mid-range product  Regular busy
# 4                              4  ...  Mid-range product    Least busy
# ...                          ...  ...                ...           ...
# 19403297                       6  ...  Low-range product  Regular busy
# 19403298                       4  ...  Low-range product    Least busy
# 19403299                       2  ...  Low-range product  Regular busy
# 19403300                       3  ...  Low-range product  Regular busy
# 19403301                       0  ...  Low-range product   Busiest day
#
#                 Result  busiest_period_of_day max_order      loyalty_flag  \
# 0         regular days            Most orders        32  Regular customer
# 1         regular days            Most orders        32  Regular customer
# 2         busiest days         Average orders         5      New customer
# 3         slowest days            Most orders         3      New customer
# 4         slowest days            Most orders         3      New customer
# ...                ...                    ...       ...               ...
# 19403297  regular days            Most orders        53    Loyal customer
# 19403298  slowest days            Most orders        53    Loyal customer
# 19403299  regular days            Most orders        53    Loyal customer
# 19403300  slowest days            Most orders        53    Loyal customer
# 19403301  busiest days            Most orders        19  Regular customer
#
#           avg_price spending_flag median_order     frequency_flag
# 0         14.790541  High Spender          8.0  Frequent Customer
# 1         14.790541  High Spender          8.0  Frequent Customer
# 2          3.062500   Low Spender          8.0  Frequent Customer
# 3          2.017241   Low Spender          9.0  Frequent Customer
# 4          2.017241   Low Spender          9.0  Frequent Customer
# ...             ...           ...          ...                ...
# 19403297  26.995283  High Spender          5.0  Frequent Customer
# 19403298  26.995283  High Spender          5.0  Frequent Customer
# 19403299  26.995283  High Spender          5.0  Frequent Customer
# 19403300  26.995283  High Spender          5.0  Frequent Customer
# 19403301   9.347826   Low Spender          7.0  Frequent Customer
#
# [19403302 rows x 25 columns]

# %%
ords_prods_merge.shape
# Out:
# (32434489, 28)

# %%
df_nan=ords_prods_merge[ords_prods_merge['median_order'].isnull()==True]

# %%
df_nan
# Out:
#           Unnamed: 0  product_id  \
# 6234909      6234909       10749
# 12947653    12947653       21334
# 13839012    13839012       22198
# 14758536    14758536       23695
#
#                                                product_name  aisle_id  \
# 6234909                             Organic Red Bell Pepper        83
# 12947653                              Organic Peeled Garlic       123
# 13839012  4X Ultra Concentrated Natural Laundry Detergen...        75
# 14758536                           California Veggie Burger        42
#
#           department_id  prices  order_id  user_id eval_set  order_number  \
# 6234909               4     5.7    895835   159838    prior             1
# 12947653              4    10.2    895835   159838    prior             1
# 13839012             17     1.7    895835   159838    prior             1
# 14758536              1     4.7    895835   159838    prior             1
#
#           ...    price_range_loc  busiest day        Result  \
# 6234909   ...  Mid-range product  Busiest day  busiest days
# 12947653  ...  Mid-range product  Busiest day  busiest days
# 13839012  ...  Low-range product  Busiest day  busiest days
# 14758536  ...  Low-range product  Busiest day  busiest days
#
#           busiest_period_of_day  max_order  loyalty_flag avg_price  \
# 6234909             Most orders          1  New customer       1.0
# 12947653            Most orders          1  New customer       1.0
# 13839012            Most orders          1  New customer       1.0
# 14758536            Most orders          1  New customer       1.0
#
#          spending_flag median_order frequency_flag
# 6234909    Low Spender          NaN            NaN
# 12947653   Low Spender          NaN            NaN
# 13839012   Low Spender          NaN            NaN
# 14758536   Low Spender          NaN            NaN
#
# [4 rows x 26 columns]

# %%
df_clean = ords_prods_merge[ords_prods_merge['median_order'].isnull()==False]

# %%
#Confirming shape is correct after removing null values in median_order field
df_clean.shape
# Out:
# (19403298, 26)

# %%
df_nan.shape
# Out:
# (4, 26)

# %%
ords_prods_merge.shape
# Out:
# (19403302, 26)

# %% [markdown]
# ## Merging customers with orders_products_merge

# %%
customers_clean.shape
# Out:
# (194950, 10)

# %%
df_all = customers_clean.merge(df_clean, on =['user_id'])

# %%
df_all.head()
# Out:
#    user_id First Name  LastName  Gender     STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    number_of_dependants family_status  income  ...    price_range_loc  \
# 0                     3       married  165665  ...  Mid-range product
# 1                     3       married  165665  ...  Mid-range product
# 2                     3       married  165665  ...  Mid-range product
# 3                     3       married  165665  ...  Low-range product
# 4                     3       married  165665  ...  Low-range product
#
#     busiest day        Result  busiest_period_of_day  max_order  loyalty_flag  \
# 0  Regular busy  busiest days            Most orders          8  New customer
# 1  Regular busy  regular days            Most orders          8  New customer
# 2  Regular busy  busiest days            Most orders          8  New customer
# 3  Regular busy  regular days            Most orders          8  New customer
# 4  Regular busy  slowest days            Most orders          8  New customer
#
#    avg_price spending_flag  median_order    frequency_flag
# 0   5.111111   Low Spender          19.0  Regular Customer
# 1   5.111111   Low Spender          19.0  Regular Customer
# 2   5.111111   Low Spender          19.0  Regular Customer
# 3   5.111111   Low Spender          19.0  Regular Customer
# 4   5.111111   Low Spender          19.0  Regular Customer
#
# [5 rows x 35 columns]

# %%
df_all.isnull().sum()
# Out:
# user_id                         0
# First Name                      0
# LastName                        0
# Gender                          0
# STATE                           0
# Age                             0
# date_joined                     0
# number_of_dependants            0
# family_status                   0
# income                          0
# Unnamed: 0                      0
# product_id                      0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# order_id                        0
# eval_set                        0
# order_number                    0
# orders_day_of_the_week          0
# order_hour_of_day               0
# days_since_prior_order    1170531
# add_to_cart_order               0
# reordered                       0
# _merge                          0
# price_range_loc                 0
# busiest day                     0
# Result                          0
# busiest_period_of_day           0
# max_order                       0
# loyalty_flag                    0
# avg_price                       0
# spending_flag                   0
# median_order                    0
# frequency_flag                  0
# dtype: int64

# %%
df_all.shape
# Out:
# (18339472, 35)

# %%
df_all.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers_merge.pkl'))
